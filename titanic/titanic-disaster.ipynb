# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="../input/titanic"
test=pd.read_csv(path + "/test.csv")
train=pd.read_csv(path+ "/train.csv")

# %%
train.head()

# %%
X=train.drop(['PassengerId','Name' , 'Parch' ,'Ticket' ,'Cabin'],axis='columns')
y=train['Survived']

# %%
X=X.drop(['Survived'],axis='columns')

# %%
from sklearn.preprocessing import LabelEncoder
Label=LabelEncoder()

X['Sex']=Label.fit_transform(X['Sex'])

# %%
X.isnull().any()

# %%
X=X.fillna(X.mean())

# %%
X['Embarked']=X['Embarked'].fillna('S')

# %%
X['Embarked']=Label.fit_transform(X['Embarked'])

# %%
X.head()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)

# %%
X=scaler.transform(X)

# %%
scaled_data=X

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=5)
pca.fit(scaled_data)

# %%
x_pca=pca.transform(scaled_data)

# %%
x_pca

# %%
print(x_pca.shape)
scaled_data.shape

# %%
test.head()

# %%
test=test.drop(['PassengerId'],axis='columns')

# %%
X=test.drop(['Name' , 'Parch' ,'Ticket' ,'Cabin'],axis='columns')

# %%
X.head()

# %%
from sklearn.preprocessing import LabelEncoder
Label=LabelEncoder()

X['Sex']=Label.fit_transform(X['Sex'])

# %%
X.isnull().any()

# %%
X=X.fillna(X.mean())

# %%
X.head()

# %%
X['Embarked']=X['Embarked'].fillna('S')

# %%
X.head()

# %%
X['Embarked']=Label.fit_transform(X['Embarked'])

# %%
X.head()

# %%
X

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)

# %%
X=scaler.transform(X)

# %%
X

# %%
test_data=pca.transform(X)

# %%
test_data

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()
logistic.fit(x_pca,y)

# %%
test1=logistic.predict(test_data)

# %%
test1

# %%
data_passenger=pd.read_csv('../input/titanic/test.csv')

# %%
data_passengerId=data_passenger['PassengerId']

# %%
df={'PassengerId' : data_passengerId,'Survived':test1}

# %%
df=pd.DataFrame(data=df)

df.to_csv('submission.csv',index=False)
df

# %%
import tensorflow as tf
